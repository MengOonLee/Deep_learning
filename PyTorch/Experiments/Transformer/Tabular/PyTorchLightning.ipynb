# %%
import pandas as pd
import torch
import lightning.pytorch as pl

class TabularDataset(torch.utils.data.Dataset):
    def __init__(self, X_num, X_cat, y):
        self.X_num = torch.tensor(data=X_num, dtype=torch.float32)
        self.X_cat = torch.tensor(data=X_cat, dtype=torch.long)
        self.y = torch.tensor(data=y, dtype=torch.float32)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X_num[idx], self.X_cat[idx], self.y[idx]

class CensusDataModule(pl.LightningDataModule):
    def __init__(self, train_url, test_url, batch_size=256):
        super().__init__()
        self.train_url = train_url
        self.test_url = test_url
        self.batch_size = batch_size

    def _load_data(self, df):
        df = df.copy().drop(columns=['fnlwgt', 'education_num']).dropna()
        df['income_bracket'] = df['income_bracket'].astype(str)\
            .str.replace('.', '').str.strip()
        y = df['income_bracket'].map({'<=50K': 0, '>50K': 1}).astype('float32')

        NUMERIC_FEATURES = ['capital_gain', 'capital_loss', 'hours_per_week']
        X_num = df[NUMERIC_FEATURES].astype('float32')
        X_cat = df.drop(columns=NUMERIC_FEATURES + ['income_bracket'])\
            .astype(str).apply(lambda s: s.str.strip())
        return X_num.values, X_cat, y.values

    def _build_category_maps(self, train_cat):
        maps = {}
        for col in train_cat.columns:
            unique_vals = sorted(train_cat[col].unique())
            maps[col] = {val: i+1 for i, val in enumerate(unique_vals)}
            maps[col]['__UNK__'] = 0
        return maps

    def _apply_category_maps(self, X_cat, maps):
        X_cat = X_cat.copy().apply(
            lambda c: c.map(maps[c.name]).fillna(0).astype(int))
        return X_cat.values

    def setup(self, stage=None):
        CSV_HEADERS = ['age', 'workclass', 'fnlwgt', 'education', 'education_num',
            'marital_status', 'occupation', 'relationship', 'race', 'gender',
            'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
            'income_bracket']
        df_train = pd.read_csv(self.train_url, header=None,
            names=CSV_HEADERS)
        df_test = pd.read_csv(self.test_url, header=0,
            names=CSV_HEADERS)

        X_num_train, X_cat_train, y_train = self._load_data(df=df_train)
        X_num_test, X_cat_test, y_test = self._load_data(df=df_test)

        self.cat_maps = self._build_category_maps(train_cat=X_cat_train)
        X_cat_train = self._apply_category_maps(X_cat=X_cat_train,
            maps=self.cat_maps)
        X_cat_test = self._apply_category_maps(X_cat=X_cat_test,
            maps=self.cat_maps)

        self.mean = X_num_train.mean(axis=0)
        self.std = X_num_train.std(axis=0)
        self.num_features = X_num_train.shape[1]
        self.cat_cardinalities = [len(self.cat_maps[c]) for c in self.cat_maps.keys()]

        self.ds_train = TabularDataset(X_num=X_num_train, X_cat=X_cat_train, y=y_train)
        ds_test = TabularDataset(X_num=X_num_test, X_cat=X_cat_test, y=y_test)
        self.ds_val, self.ds_test = torch.utils.data.random_split(dataset=ds_test,
            lengths=[0.5, 0.5], generator=torch.Generator().manual_seed(42))

    def train_dataloader(self):
        return torch.utils.data.DataLoader(dataset=self.ds_train,
            batch_size=self.batch_size, shuffle=True, num_workers=7)

    def val_dataloader(self):
        return torch.utils.data.DataLoader(dataset=self.ds_val,
            batch_size=self.batch_size, num_workers=7)

    def test_dataloader(self):
        return torch.utils.data.DataLoader(dataset=self.ds_test,
            batch_size=self.batch_size, num_workers=7)

# %%
import torch
import lightning.pytorch as pl

class Normalization(torch.nn.Module):
    def __init__(self, mean, std):
        super().__init__()
        self.register_buffer('mean', torch.tensor(data=mean, dtype=torch.float32))
        self.register_buffer('std', torch.tensor(data=std, dtype=torch.float32))

    def forward(self, x):
        return (x - self.mean) / self.std

class ClassifyModel(pl.LightningModule):
    def __init__(self, num_features, cat_cardinalities, mean, std):
        super().__init__()

        self.normalizer = Normalization(mean=mean, std=std)

        self.emb_layers = torch.nn.ModuleList(modules=[
            torch.nn.Embedding(num_embeddings=c+1, embedding_dim=min(8, (c+1)//2))
            for c in cat_cardinalities
        ])
        emb_out_dim = sum(e.embedding_dim for e in self.emb_layers)

        self.fc = torch.nn.Sequential(
            torch.nn.Linear(in_features=num_features + emb_out_dim, out_features=128),
            torch.nn.ReLU(),
            torch.nn.Dropout(p=0.3),
            torch.nn.Linear(in_features=128, out_features=64),
            torch.nn.ReLU(),
            torch.nn.Dropout(p=0.3),
            torch.nn.Linear(in_features=64, out_features=1),
            torch.nn.Sigmoid()
        )

        self.criterion = torch.nn.BCELoss()

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=0.001)

    def forward(self, x_num, x_cat):
        x_num = self.normalizer(x_num)
        x_emb = [emb(x_cat[:, i]) for i, emb in enumerate(self.emb_layers)]
        x_emb = torch.cat(tensors=x_emb, dim=1)
        x = torch.cat(tensors=[x_num, x_emb], dim=1)
        return self.fc(x)

    def training_step(self, batch, batch_idx):
        x_num, x_cat, y = batch
        preds = self(x_num=x_num, x_cat=x_cat).squeeze()
        loss = self.criterion(preds, y)
        self.log('train_loss', loss)
        return loss

    def validation_step(self, batch, batch_idx):
        x_num, x_cat, y = batch
        preds = self(x_num=x_num, x_cat=x_cat).squeeze()
        loss = self.criterion(preds, y)
        self.log('val_loss', loss)
        acc = ((preds > 0.5).float()==y).float().mean()
        self.log('val_acc', acc)

    def test_step(self, batch, batch_idx):
        x_num, x_cat, y = batch
        preds = self(x_num, x_cat).squeeze()
        acc = ((preds > 0.5).float()==y).float().mean()
        self.log('test_acc', acc)

# %%
import lightning.pytorch as pl

if __name__ == '__main__':
    train_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
    test_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test'
    datamodule = CensusDataModule(train_url=train_url, test_url=test_url)
    datamodule.setup()

    model = ClassifyModel(
        num_features=datamodule.num_features,
        cat_cardinalities=datamodule.cat_cardinalities,
        mean=datamodule.mean,
        std=datamodule.std
    )

    trainer = pl.Trainer(max_epochs=3, accelerator='auto', devices=1)
    trainer.fit(model=model, datamodule=datamodule)
    trainer.test(model=model, datamodule=datamodule)
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /home/Work/venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/logger_connector/logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `lightning.pytorch` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
#
#   | Name       | Type          | Params | Mode
# -----------------------------------------------------
# 0 | normalizer | Normalization | 0      | train
# 1 | emb_layers | ModuleList    | 1.4 K  | train
# 2 | fc         | Sequential    | 15.2 K | train
# 3 | criterion  | BCELoss       | 0      | train
# -----------------------------------------------------
# 16.6 K    Trainable params
# 0         Non-trainable params
# 16.6 K    Total params
# 0.066     Total estimated model params size (MB)
# 21        Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|██████████████████████| 128/128 [00:01<00:00, 122.57it/s, v_num=0]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/32 [00:00<?, ?it/s]
# Validation DataLoader 0:   3%|▌                 | 1/32 [00:00<00:00, 118.17it/s]
# Validation DataLoader 0:   6%|█▏                | 2/32 [00:00<00:00, 143.25it/s]
# Validation DataLoader 0:   9%|█▋                | 3/32 [00:00<00:00, 144.89it/s]
# Validation DataLoader 0:  12%|██▎               | 4/32 [00:00<00:00, 151.67it/s]
# Validation DataLoader 0:  16%|██▊               | 5/32 [00:00<00:00, 156.73it/s]
# Validation DataLoader 0:  19%|███▍              | 6/32 [00:00<00:00, 157.01it/s]
# Validation DataLoader 0:  22%|███▉              | 7/32 [00:00<00:00, 161.01it/s]
# Validation DataLoader 0:  25%|████▌             | 8/32 [00:00<00:00, 158.49it/s]
# Validation DataLoader 0:  28%|█████             | 9/32 [00:00<00:00, 158.14it/s]
# Validation DataLoader 0:  31%|█████▎           | 10/32 [00:00<00:00, 161.92it/s]
# Validation DataLoader 0:  34%|█████▊           | 11/32 [00:00<00:00, 164.28it/s]
# Validation DataLoader 0:  38%|██████▍          | 12/32 [00:00<00:00, 164.58it/s]
# Validation DataLoader 0:  41%|██████▉          | 13/32 [00:00<00:00, 168.47it/s]
# Validation DataLoader 0:  44%|███████▍         | 14/32 [00:00<00:00, 171.35it/s]
# Validation DataLoader 0:  47%|███████▉         | 15/32 [00:00<00:00, 169.72it/s]
# Validation DataLoader 0:  50%|████████▌        | 16/32 [00:00<00:00, 170.18it/s]
# Validation DataLoader 0:  53%|█████████        | 17/32 [00:00<00:00, 167.54it/s]
# Validation DataLoader 0:  56%|█████████▌       | 18/32 [00:00<00:00, 169.23it/s]
# Validation DataLoader 0:  59%|██████████       | 19/32 [00:00<00:00, 172.20it/s]
# Validation DataLoader 0:  62%|██████████▋      | 20/32 [00:00<00:00, 174.30it/s]
# Validation DataLoader 0:  66%|███████████▏     | 21/32 [00:00<00:00, 174.89it/s]
# Validation DataLoader 0:  69%|███████████▋     | 22/32 [00:00<00:00, 176.26it/s]
# Validation DataLoader 0:  72%|████████████▏    | 23/32 [00:00<00:00, 178.48it/s]
# Validation DataLoader 0:  75%|████████████▊    | 24/32 [00:00<00:00, 178.65it/s]
# Validation DataLoader 0:  78%|█████████████▎   | 25/32 [00:00<00:00, 179.66it/s]
# Validation DataLoader 0:  81%|█████████████▊   | 26/32 [00:00<00:00, 181.69it/s]
# Validation DataLoader 0:  84%|██████████████▎  | 27/32 [00:00<00:00, 183.06it/s]
# Validation DataLoader 0:  88%|██████████████▉  | 28/32 [00:00<00:00, 183.53it/s]
# Validation DataLoader 0:  91%|███████████████▍ | 29/32 [00:00<00:00, 185.09it/s]
# Validation DataLoader 0:  94%|███████████████▉ | 30/32 [00:00<00:00, 186.17it/s]
# Validation DataLoader 0:  97%|████████████████▍| 31/32 [00:00<00:00, 186.49it/s]
# Validation DataLoader 0: 100%|█████████████████| 32/32 [00:00<00:00, 187.18it/s]
# Epoch 1: 100%|██████████████████████| 128/128 [00:01<00:00, 114.73it/s, v_num=0]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/32 [00:00<?, ?it/s]
# Validation DataLoader 0:   3%|▌                  | 1/32 [00:00<00:00, 90.94it/s]
# Validation DataLoader 0:   6%|█▏                | 2/32 [00:00<00:00, 117.38it/s]
# Validation DataLoader 0:   9%|█▋                | 3/32 [00:00<00:00, 124.92it/s]
# Validation DataLoader 0:  12%|██▎               | 4/32 [00:00<00:00, 128.67it/s]
# Validation DataLoader 0:  16%|██▊               | 5/32 [00:00<00:00, 130.09it/s]
# Validation DataLoader 0:  19%|███▍              | 6/32 [00:00<00:00, 130.87it/s]
# Validation DataLoader 0:  22%|███▉              | 7/32 [00:00<00:00, 138.73it/s]
# Validation DataLoader 0:  25%|████▌             | 8/32 [00:00<00:00, 139.63it/s]
# Validation DataLoader 0:  28%|█████             | 9/32 [00:00<00:00, 145.16it/s]
# Validation DataLoader 0:  31%|█████▎           | 10/32 [00:00<00:00, 151.21it/s]
# Validation DataLoader 0:  34%|█████▊           | 11/32 [00:00<00:00, 155.75it/s]
# Validation DataLoader 0:  38%|██████▍          | 12/32 [00:00<00:00, 157.17it/s]
# Validation DataLoader 0:  41%|██████▉          | 13/32 [00:00<00:00, 160.44it/s]
# Validation DataLoader 0:  44%|███████▍         | 14/32 [00:00<00:00, 164.36it/s]
# Validation DataLoader 0:  47%|███████▉         | 15/32 [00:00<00:00, 164.09it/s]
# Validation DataLoader 0:  50%|████████▌        | 16/32 [00:00<00:00, 165.30it/s]
# Validation DataLoader 0:  53%|█████████        | 17/32 [00:00<00:00, 166.80it/s]
# Validation DataLoader 0:  56%|█████████▌       | 18/32 [00:00<00:00, 166.00it/s]
# Validation DataLoader 0:  59%|██████████       | 19/32 [00:00<00:00, 167.84it/s]
# Validation DataLoader 0:  62%|██████████▋      | 20/32 [00:00<00:00, 168.83it/s]
# Validation DataLoader 0:  66%|███████████▏     | 21/32 [00:00<00:00, 169.16it/s]
# Validation DataLoader 0:  69%|███████████▋     | 22/32 [00:00<00:00, 170.34it/s]
# Validation DataLoader 0:  72%|████████████▏    | 23/32 [00:00<00:00, 170.86it/s]
# Validation DataLoader 0:  75%|████████████▊    | 24/32 [00:00<00:00, 170.62it/s]
# Validation DataLoader 0:  78%|█████████████▎   | 25/32 [00:00<00:00, 171.94it/s]
# Validation DataLoader 0:  81%|█████████████▊   | 26/32 [00:00<00:00, 173.28it/s]
# Validation DataLoader 0:  84%|██████████████▎  | 27/32 [00:00<00:00, 173.05it/s]
# Validation DataLoader 0:  88%|██████████████▉  | 28/32 [00:00<00:00, 174.26it/s]
# Validation DataLoader 0:  91%|███████████████▍ | 29/32 [00:00<00:00, 175.48it/s]
# Validation DataLoader 0:  94%|███████████████▉ | 30/32 [00:00<00:00, 175.15it/s]
# Validation DataLoader 0:  97%|████████████████▍| 31/32 [00:00<00:00, 175.67it/s]
# Validation DataLoader 0: 100%|█████████████████| 32/32 [00:00<00:00, 176.69it/s]
# Epoch 2: 100%|██████████████████████| 128/128 [00:01<00:00, 114.69it/s, v_num=0]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/32 [00:00<?, ?it/s]
# Validation DataLoader 0:   3%|▌                 | 1/32 [00:00<00:00, 133.79it/s]
# Validation DataLoader 0:   6%|█▏                | 2/32 [00:00<00:00, 150.41it/s]
# Validation DataLoader 0:   9%|█▋                | 3/32 [00:00<00:00, 100.65it/s]
# Validation DataLoader 0:  12%|██▎               | 4/32 [00:00<00:00, 113.39it/s]
# Validation DataLoader 0:  16%|██▊               | 5/32 [00:00<00:00, 119.93it/s]
# Validation DataLoader 0:  19%|███▍              | 6/32 [00:00<00:00, 121.66it/s]
# Validation DataLoader 0:  22%|███▉              | 7/32 [00:00<00:00, 124.50it/s]
# Validation DataLoader 0:  25%|████▌             | 8/32 [00:00<00:00, 130.40it/s]
# Validation DataLoader 0:  28%|█████             | 9/32 [00:00<00:00, 136.93it/s]
# Validation DataLoader 0:  31%|█████▎           | 10/32 [00:00<00:00, 141.79it/s]
# Validation DataLoader 0:  34%|█████▊           | 11/32 [00:00<00:00, 146.22it/s]
# Validation DataLoader 0:  38%|██████▍          | 12/32 [00:00<00:00, 149.23it/s]
# Validation DataLoader 0:  41%|██████▉          | 13/32 [00:00<00:00, 153.59it/s]
# Validation DataLoader 0:  44%|███████▍         | 14/32 [00:00<00:00, 154.44it/s]
# Validation DataLoader 0:  47%|███████▉         | 15/32 [00:00<00:00, 154.75it/s]
# Validation DataLoader 0:  50%|████████▌        | 16/32 [00:00<00:00, 157.89it/s]
# Validation DataLoader 0:  53%|█████████        | 17/32 [00:00<00:00, 158.28it/s]
# Validation DataLoader 0:  56%|█████████▌       | 18/32 [00:00<00:00, 158.10it/s]
# Validation DataLoader 0:  59%|██████████       | 19/32 [00:00<00:00, 160.93it/s]
# Validation DataLoader 0:  62%|██████████▋      | 20/32 [00:00<00:00, 162.73it/s]
# Validation DataLoader 0:  66%|███████████▏     | 21/32 [00:00<00:00, 164.48it/s]
# Validation DataLoader 0:  69%|███████████▋     | 22/32 [00:00<00:00, 166.77it/s]
# Validation DataLoader 0:  72%|████████████▏    | 23/32 [00:00<00:00, 168.46it/s]
# Validation DataLoader 0:  75%|████████████▊    | 24/32 [00:00<00:00, 170.80it/s]
# Validation DataLoader 0:  78%|█████████████▎   | 25/32 [00:00<00:00, 172.19it/s]
# Validation DataLoader 0:  81%|█████████████▊   | 26/32 [00:00<00:00, 173.99it/s]
# Validation DataLoader 0:  84%|██████████████▎  | 27/32 [00:00<00:00, 174.93it/s]
# Validation DataLoader 0:  88%|██████████████▉  | 28/32 [00:00<00:00, 175.05it/s]
# Validation DataLoader 0:  91%|███████████████▍ | 29/32 [00:00<00:00, 175.57it/s]
# Validation DataLoader 0:  94%|███████████████▉ | 30/32 [00:00<00:00, 176.86it/s]
# Validation DataLoader 0:  97%|████████████████▍| 31/32 [00:00<00:00, 177.73it/s]
# Validation DataLoader 0: 100%|█████████████████| 32/32 [00:00<00:00, 177.80it/s]
# Epoch 2: 100%|███████████████████████| 128/128 [00:01<00:00, 88.01it/s, v_num=0]
# `Trainer.fit` stopped: `max_epochs=3` reached.
# Epoch 2: 100%|███████████████████████| 128/128 [00:01<00:00, 87.53it/s, v_num=0]
# Testing DataLoader 0: 100%|████████████████████| 32/32 [00:00<00:00, 291.11it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.8509827852249146
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
