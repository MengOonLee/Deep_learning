# %% [markdown]
# <a href="https://colab.research.google.com/github/MengOonLee/Deep_learning/blob/master/TensorFlow/Probabilistic/Distributions/Distributions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tensorflow Distributions

# %% [markdown]
# ## Coding Tutorials
# #### 1. [Univariate Distributions](#univariate_distributions)
# #### 2. [Multivariate Distributions](#multivariate_distributions)
# #### 3. [The Independent Distribution](#the_independent_distribution)
# #### 4. [Sampling and log probs](#sampling_and_log_probs)
# #### 5. [Trainable Distributions](#trainable_distributions)

# %%
# %%bash
# pip install --no-cache-dir -qU \
#  tensorflow tensorflow-probability[tf]
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 60.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.5/615.5 MB 100.9 MB/s eta 0:00:00

# %% [markdown]
# ***
# ## Univariate distributions
# <a id='univariate_distributions'></a>

# %%
import tensorflow as tf
import tensorflow_probability as tfp
tf.keras.utils.set_random_seed(seed=42)
import matplotlib.pyplot as plt
import seaborn as sns

# Create a normal distribution from Tensorflow Distributions
distrib = tfp.distributions.Normal(loc=[0.], scale=[0.1, 1., 10.])
print(distrib)
# Sample multiple times from the chosen distribution...
sample = distrib.sample(sample_shape=1000)
# Obtain value of probability's density
prob = distrib.prob(value=sample)

# Plot a histogram, approximating the density
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(9, 3))
for i, ax in enumerate(axes):
    sns.histplot(ax=ax, x=sample[:, i], bins=100,
        stat="density", color="blue")
    sns.lineplot(ax=ax, x=sample[:, i], y=prob[:, i], color="red")
    ax.set_title(label="loc={:.1f}, scale={:.1f}".format(
        distrib.loc[0], distrib.scale[i]))
    ax.set_xlabel(xlabel="x")
fig.tight_layout()
plt.show()
# Out:
# tfp.distributions.Normal("Normal", batch_shape=[3], event_shape=[], dtype=float32)

# %% [markdown]
# #### Work with batch distributions

# %%
import tensorflow as tf
import tensorflow_probability as tfp
tf.keras.utils.set_random_seed(seed=42)
import matplotlib.pyplot as plt
import seaborn as sns

# Create a batched Bernoulli distribution (discrete)
distrib = tfp.distributions.Bernoulli(probs=[0.25, 0.45, 0.8])
print(distrib)
# Sample from this batch of distributions
sample = distrib.sample(sample_shape=1000)
# Determine probabilities from this batch distribution
prob = distrib.prob(value=sample)

# Plot a histogram, approximating the density
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(9, 3))
for i, ax in enumerate(axes):
    sns.histplot(ax=ax, x=sample[:, i], bins=100,
        stat="probability", color="blue")
    sns.scatterplot(ax=ax, x=sample[:, i], y=prob[:, i], color="red")
    ax.set_title(label="prob={:.2f}".format(distrib.probs[i]))
    ax.set_xlabel(xlabel="x")
fig.tight_layout()
plt.show()
# Out:
# tfp.distributions.Bernoulli("Bernoulli", batch_shape=[3], event_shape=[], dtype=int32)

# %% [markdown]
# ***
# <a id='multivariate_distributions'></a>
# ## Multivariate Distributions

# %% [markdown]
# #### Batches of multivariate distributions

# %%
import tensorflow as tf
import tensorflow_probability as tfp
tf.keras.utils.set_random_seed(seed=42)
import matplotlib.pyplot as plt
import seaborn as sns

# Define 2D multivariate Gaussian with diagonal covariance matrix
# Create three "batches" of multivariate normals
distrib = tfp.distributions.MultivariateNormalDiag(
    loc=[[0., 0.]], scale_diag=[[1., 2.], [2., 1.], [2., 2.]])
print(distrib)

# Create a sample for a plot -- notice the shape
sample = distrib.sample(sample_shape=1000)

# Plot samples from the batched multivariate Gaussian
fig, axes = plt.subplots(nrows=1, ncols=3,
    sharex=True, sharey=True, figsize=(9, 3))
for i, ax in enumerate(axes):
    # take the ith batch [samples x event_shape]
    plt_sample = sample[:, i, :]
    sns.scatterplot(ax=ax, x=plt_sample[:, 0], y=plt_sample[:, 1],
        marker=".", color="blue")
    ax.set_title(label="loc={}, scale={}".format(
        distrib.loc[0], distrib.scale.diag[i]))
    ax.set_xlabel(xlabel="x1")
    ax.set_ylabel(ylabel="x2")
fig.tight_layout()
plt.show()
# Out:
# tfp.distributions.MultivariateNormalDiag("MultivariateNormalDiag", batch_shape=[3], event_shape=[2], dtype=float32)

# %% [markdown]
# ***
# <a id='the_independent_distribution'></a>
# ## The Independent Distribution

# %%
import tensorflow as tf
tf.keras.utils.set_random_seed(seed=42)
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
import seaborn as sns

# Start by defining a batch of two univariate Gaussians, then
# combine them into a bivariate Gaussian with independent components
distrib = tfp.distributions.Normal(loc=[-1., 1.], scale=[0.5, 1.])
# Check the distribution
print(distrib)
# Univariate density functions
# each column is a vector of densities for one distribute normal
sample = distrib.sample(sample_shape=1000)
prob = distrib.prob(value=sample)

plt.figure(figsize=(9, 3))
for i in range(2):
    sns.lineplot(x=sample[:, i], y=prob[:, i],
        label="loc={:.1f}, scale={:.1f}".format(
            distrib.loc[i], distrib.scale[i]))
plt.title(label="Univariate Normal Distribution")
plt.ylabel(ylabel="pdf")
plt.xlabel(xlabel="x")
plt.legend()
plt.tight_layout()
plt.show()

# Summarise how Independent has been used
# Use Independent to convert the batch shape to the event shape
distrib = tfp.distributions.Independent(
    distribution=distrib, reinterpreted_batch_ndims=1)
# Note that dimension from batch_shape has shifted to event_shape
print(distrib)
# Create a plot showing joint density contours and marginal density functions
sample = distrib.sample(sample_shape=1000)

g = sns.jointplot(x=sample[:, 0], y=sample[:, 1], kind="kde")
g.fig.suptitle(t="loc={}, scale={}".format(
    distrib.distribution.loc, distrib.distribution.scale))
g.set_axis_labels(xlabel="x1", ylabel="x2")
plt.tight_layout()
plt.show()
# Out:
# tfp.distributions.Normal("Normal", batch_shape=[2], event_shape=[], dtype=float32)
# tfp.distributions.Independent("IndependentNormal", batch_shape=[], event_shape=[2], dtype=float32)

# %% [markdown]
# #### Shifting batch dimensions to event dimensions using `reinterpreted_batch_ndims`

# %%
import tensorflow as tf
tf.keras.utils.set_random_seed(seed=42)
import tensorflow_probability as tfp

# Demonstrate use of reinterpreted batch ndims
distrib = tfp.distributions.Normal(
    loc=[[-1.], [0.], [1.]], scale=[1., 10.])
print(distrib)

distrib = tfp.distributions.Independent(
    distribution=distrib, reinterpreted_batch_ndims=2)
print(distrib)

sample = tf.random.normal(shape=[10, 3, 2])
prob = distrib.prob(value=sample)
print("Prob shape", prob.shape)
# Out:
# tfp.distributions.Normal("Normal", batch_shape=[3, 2], event_shape=[], dtype=float32)
# tfp.distributions.Independent("IndependentNormal", batch_shape=[], event_shape=[3, 2], dtype=float32)
# Prob shape (10,)

# %% [markdown]
# ***
# <a id='sampling_and_log_probs'></a>
# ## Sampling and log probs

# %%
import tensorflow as tf
tf.keras.utils.set_random_seed(seed=42)
import tensorflow_probability as tfp

# Multivariate Normal batched Distribution
# We are broadcasting batch shapes of `loc` and `scal_diag`
# against each other

loc = tf.constant(value=[
    [[0.3, 1.5, 1.], [0.2, 0.4, 2.8]],
    [[2., 2.3, 8.], [1.4, 1., 1.3]]
], dtype=tf.float32) # (2, 2, 3)
scale_diag = tf.constant(value=[0.4, 1., 0.7], dtype=tf.float32) # (3,)
distrib = tfp.distributions.MultivariateNormalDiag(
    loc=loc, scale_diag=scale_diag)
print(distrib)

# Use independent to move part of the batch shape
distrib = tfp.distributions.Independent(
    distribution=distrib, reinterpreted_batch_ndims=1)
print(distrib)

# `[S, b, e]` shaped input, where [b, e] is broadcastable over [B, E]
sample = tf.random.normal(shape=(10, 1, 2, 1))
print("Log_prob shape", distrib.log_prob(value=sample).shape)
# Out:
# tfp.distributions.MultivariateNormalDiag("MultivariateNormalDiag", batch_shape=[2, 2], event_shape=[3], dtype=float32)
# tfp.distributions.Independent("IndependentMultivariateNormalDiag", batch_shape=[2], event_shape=[2, 3], dtype=float32)
# Log_prob shape (10, 2)

# %% [markdown]
# ***
# <a id='trainable_distributions'></a>
# ## Trainable Distributions

# %%
import tensorflow as tf
import tensorflow_probability as tfp
tf.keras.utils.set_random_seed(seed=42)
import time
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sample = tf.random.normal(shape=(1000,), mean=2., stddev=5.)
ds = tf.data.Dataset.from_tensor_slices(tensors=(sample)).cache()
ds = ds.shuffle(buffer_size=len(sample)).batch(batch_size=64)
ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)

distrib = tfp.distributions.Normal(
    loc=tf.Variable(initial_value=0., name="loc"),
    scale=tf.Variable(initial_value=1., name="scale")
)

def loss_fn(y_true, y_pred):
    return -tf.math.reduce_mean(input_tensor=y_pred.log_prob(value=y_true))
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
metric = tf.keras.metrics.Mean(name="loss")

@tf.function(reduce_retracing=True)
def train_step(x):
    with tf.GradientTape() as tape:
        loss = loss_fn(y_true=x, y_pred=distrib)
    vars = distrib.trainable_variables
    grads = tape.gradient(target=loss, sources=vars)
    optimizer.apply_gradients(grads_and_vars=zip(grads, vars))
    metric.update_state(values=loss)
    return metric.result()

start_time = time.time()
history = {"loss": [], "loc": [], "scale": []}
for _ in range(50):
    for x in ds:
        loss = train_step(x=x)
    history["loss"].append(loss.numpy())
    history["loc"].append(distrib.loc.numpy())
    history["scale"].append(distrib.scale.numpy())
    metric.reset_state()
print("Training duration: %2.fs"%(time.time() - start_time))

df_history = pd.DataFrame(history)
df_history["epoch"] = df_history.index + 1
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(9, 3))
fig.suptitle(t="Convergence", fontsize=12)
for ax, metric in zip(axes, ["loss", "loc", "scale"]):
    sns.lineplot(ax=ax, data=df_history, x="epoch", y=f"{metric}")
    ax.set_ylabel(ylabel=f"{metric}")
    ax.set_xlabel(xlabel="epoch")
    ax.set_title(label=f"{metric} vs. epoch")
fig.tight_layout()
fig.show()

plt.figure(figsize=(9, 3))
sns.histplot(x=sample, stat="density", bins=100,
    label="sample", color="blue")
sns.lineplot(x=sample, y=distrib.prob(value=sample),
    label="predict", color="red")
plt.ylabel(ylabel="Probability density")
plt.xlabel(xlabel="x")
plt.legend(loc="best")
plt.show()
# Out:
# Training duration:  2s

# %% [markdown]
# ## Naive Bayes classifier

# %% [markdown]
# ### Introduction to `newsgroups` data set

# %% [markdown]
# In this tutorial, just load the dataset, fetch train/test splits, probably choose a subset of the data.
#
# Construct the class conditional feature distribution (with Independent, using the Naive Bayes assumption) and sample from it.
#
# We can just use the ML estimates for parameters, in later tutorials we will learn them.

# %%
# Convenience function for retrieving the 20 newsgroups data set
# Usenet was a forerunner to modern internet forums
# Users could post and read articles
# Newsgroup corresponded to a topic
# Example topics in this data set: IBM computer hardware, baseball
# Our objective is to use an article's contents to predict its newsgroup,
# a 20-class classification problem.
# 18000 newsgroups, posts on 20 topics

from sklearn import datasets
import numpy as np

# Get the data
newsgrp_train = datasets.fetch_20newsgroups(data_home="data/newsgrp",
    subset="train", shuffle=True)
len(newsgrp_train["target_names"])

# Name of label
# print("Target name:\n", np.unique(newsgrp_train["target_names"]))
# Out:
# 20

# %%
from sklearn import datasets, feature_extraction

# Making a function get_data which:
#   1) Fetches the 20 newsgroup dataset
#   2) Performs a word count on the articles and binarizes the result
#   3) Returns the data as a numpy matrix with the labels

def get_data(categories, subset):
    data = datasets.fetch_20newsgroups(
        data_home="data/newsgrp", subset=subset,
        categories=categories)
    return data["data"], data["target"], data["target_names"]

# Getting a subset of the 20 newsgroup dataset
categories = ["alt.atheism", "talk.religion.misc", "comp.graphics",
    "sci.space"]
x_train, y_train, category_train = get_data(categories=categories,
    subset="train")
x_test, y_test, category_test = get_data(categories=categories,
    subset="test")

# Preprocessing boilerplate
# Ignore common words, words that appear once
vectorizer = feature_extraction.text.CountVectorizer(input="content",
    binary=True, max_df=0.25, min_df=1.01/len(y_train))

# Input is a list of strings
x_train = vectorizer.fit_transform(raw_documents=x_train)
x_test = vectorizer.transform(raw_documents=x_test)

# Check shape
print("x_train shape:", x_train.shape)
# Check that the fit has been successful
vectorizer.inverse_transform(x_train[1, :])
# Out:
# x_train shape: (2034, 17495)
# [array(['nothing', 'biblical', 'backing', 'koresh', '02', 'tape', 'cites',
#         'enclosed', 'almanac', 'bc', 'ca', 'ken', 'old', 'frog', '20',
#         '20apr199301460499', 'utarlg', 'uta', 'b645zaw', 'stephen',
#         'seems', 'yet', 'another', 'messenger', 'got', 'killed', 'message',
#         'he', 'carried', 'says', 'evidence', 'contrary', 'simply',
#         'fanatic', 'thought', 'neccessary', 'take', 'whole', 'bunch',
#         'folks', 'him', 'children', 'satisfy', 'his', 'delusional',
#         'mania', 'jim', 'jones', 'circa', '1993', 'mean', 'time', 'sure',
#         'learned', 'lot', 'evil', 'corruption', 'surprised', 'things',
#         'gotten', 'rotten', 'nope', 'been', 'demonstrating', 'such',
#         'centuries', '604', '245', 'v32', 'sco', 'gt', 'british',
#         'columbia', 'canada', 'serving', 'central', 'vancouver', 'island',
#         'public', 'access', 'usenet', 'internet', 'mail', 'home',
# ...

# %% [markdown]
# #### A Naive Bayes classifier for `newsgroup`

# %% [markdown]
# Each feature vector $x$ is a list of indicators for whether a word appears in the article. $x_i$ is 1 if the $i$th word appears, and 0 otherwise. `inv_vocab` matches word indices $i$ to words.
#
# Each label $y$ is a value in $0, 1, \ldots, 19$.
#
# The parts of a naive Bayes classifier for this problem can be summarised as:
#
#
# - A probability distribution for the feature vector by class, $p(x|y = j)$ for each $j = 0, 1, \ldots, 19$. These probability distributions are assumed to have independent components: we can factorize the joint probability as a product of marginal probabilities
# \begin{equation}
#     p(x|y = j) = \prod_{i=1}^d p(x_i|y = j)
# \end{equation}
# These marginal probability distributions are Bernoulli distributions, each of which has a single parameter $\theta_{ji} := p(x_i = 1|y = j)$. This parameter is the probability of observing word $i$ in an article of class $j$.
#
# - We will use the Laplace smoothed maximum likelihood estimate to compute these parameters. Laplace smoothing involves adding small counts to every feature for each class. Else, if a feature did not appear in the training set of a class, but then we observed it in our test data the log probability would be undefined.
#
# - A collection of class prior probabilities $p(y = j)$. These will be set by computing the class base rates in the training set.
#
#
# - A function for computing the probability of class membership via Bayes' theorem:
#
# \begin{equation}
#     p(y = j|x) = \frac{p(x|y = j)p(y = j)}{p(x)}
# \end{equation}

# %%
import numpy as np

# Defining a function to conduct Laplace smoothing. This adds a base
# level of probability for a given feature to occur in every class.
def laplace_smoothing(x, y):
    # Compute the parameter estimates (adjusted fraction of documents
    # in class that contain word)
    n_classes = y.max() + 1
    n_words = x.shape[1]
    # parameters for Laplace smoothing
    alpha = 0.01
    # stores parameter values - prob. word given class
    theta = np.zeros([n_classes, n_words])
    # 0, 1, ..., 19
    for c in range(n_classes):
        class_mask = (y==c)
        # number of articles in class
        N = class_mask.sum()
        theta[c, :] = (x[class_mask, :].sum(axis=0) + alpha)/(N + 2*alpha)
    return theta

theta = laplace_smoothing(x=x_train, y=y_train)
print("theta shape:", theta.shape)

# Check whether the most probable word in each class is reasonable
# most probable word for each class
most_word = theta.argmax(axis=1)
# Dict that will be useful later
vocab = {v: k for k, v in vectorizer.vocabulary_.items()}
for j, i in enumerate(most_word):
    print("Most probable word in class %s is %s"%(
        category_train[j], vocab[i]))
# Out:
# theta shape: (4, 17495)
# Most probable word in class alt.atheism is people
# Most probable word in class comp.graphics is graphics
# Most probable word in class sci.space is space
# Most probable word in class talk.religion.misc is he

# %% [markdown]
# To now make our NB classifier we need to build three functions:
# * Compute the class priors
# * Build our class conditional distributions
# * Put it all together and classify our data

# %%
import numpy as np

# Function which computes the prior probability of every class
# based on frequency of occurence in the dataset

def class_prior(y):
    n_class = y.max() + 1
    count = np.zeros(n_class, dtype=np.float32)
    for c in range(n_class):
        count[c] = np.sum(np.where(y==c, 1, 0))
    prior = count / np.sum(count)
    return prior

# Run the function
prior = class_prior(y=y_train)
print('The class prior are {}'.format(prior))
# Out:
# The class prior are [0.2359882  0.28711897 0.29154375 0.18534906]

# %%
import tensorflow as tf
import tensorflow_probability as tfp
tf.random.set_seed(seed=42)

# Now we will do a function that given the feature occurence counts
# returns a Bernoulli distribution of batch_shape=number of classes
# and event_shape=number of features.

def get_distribution(probs):
    distrib = tfp.distributions.Bernoulli(probs=probs)
    distrib = tfp.distributions.Independent(
        distribution=distrib, reinterpreted_batch_ndims=1)
    return distrib

distrib = get_distribution(probs=theta)
distrib
# Out:
# <tfp.distributions.Independent 'IndependentBernoulli' batch_shape=[4] event_shape=[17495] dtype=int32>

# %% [markdown]
# #### Computing log_probs

# %%
import tensorflow as tf
tf.random.set_seed(seed=42)
import numpy as np
from sklearn import metrics

# The final function predict_sample which given the distribution,
#  a test sample, and the class priors:
#   1) Computes the class conditional probabilities given the sample
#   2) Forms the joint likelihood
#   3) Normalises the joint likelihood and returns the log prob

def predict_log_prob(distribution, prior, sample):
    conditional_prob = distribution.log_prob(value=sample.todense())
    joint_likelihood = tf.math.add(
        x=tf.math.log(prior), y=conditional_prob)
    norm_factor = tf.math.reduce_logsumexp(
        input_tensor=joint_likelihood)
    log_prob = joint_likelihood - norm_factor
    return log_prob

# Loop over our test data and classify.
log_probs = []
for x in x_test:
    log_prob = predict_log_prob(
        distribution=distrib, prior=prior, sample=x)
    log_probs.append(log_prob)

y_pred = np.argmax(log_probs, axis=-1)
print("F1 from tfp:", metrics.f1_score(average="macro",
    y_true=y_test, y_pred=y_pred))
# Out:
# F1 from tfp: 0.8623389692276502

# %%
from sklearn import naive_bayes, metrics

# Make a Bernoulli Naive Bayes classifier using
# sklearn with the same level of alpha smoothing.

clf = naive_bayes.BernoulliNB(alpha=0.01)
clf.fit(X=x_train, y=y_train)
y_pred = clf.predict(X=x_test)
print("F1 from sklean:", metrics.f1_score(average="macro",
    y_true=y_test, y_pred=y_pred))
# Out:
# F1 from sklean: 0.8623389692276502

# %%
import tensorflow as tf
import tensorflow_probability as tfp
tf.random.set_seed(seed=42)
import time
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns

def nll(y_true, y_pred):
    return -tf.math.reduce_mean(
        input_tensor=y_pred.log_prob(value=y_true))

class TrainStep(tf.Module):
    def __init__(self, optimizer):
        super().__init__()
        self.optimizer = optimizer

    @tf.function
    def __call__(self, distrib, data):
        vars = distrib.trainable_variables
        with tf.GradientTape() as tape:
            loss = nll(y_true=data, y_pred=distrib)
            grads = tape.gradient(target=loss, sources=vars)
        self.optimizer.apply_gradients(grads_and_vars=zip(grads, vars))
        clip_prob = tf.clip_by_value(t=vars,
            clip_value_min=1e-3, clip_value_max=1)
        prob = tf.squeeze(input=clip_prob)
        return loss, prob

# Now we learn the distribution using gradient tape
def get_trained_distribution(x, y):
    n_classes = y.max() + 1
    probs = []
    for c in range(n_classes):
        print('\n%-------------------%')
        print('Class ', c)
        print('%-------------------%')
        mask = (y==c)
        data = x[mask, :].todense()

        theta = tf.Variable(initial_value=tf.random.uniform(
            minval=0.01, maxval=0.1, shape=[data.shape[-1]]))
        distrib = tfp.distributions.Bernoulli(probs=theta)
        train_step = TrainStep(optimizer=tf.keras.optimizers.Adam())

        losses = []
        for _ in range(100):
            loss, prob = train_step(distrib=distrib, data=data)
            losses.append(loss.numpy())
        probs.append(prob)

        plt.figure(figsize=(12, 3))
        sns.lineplot(x=range(100), y=losses)
        plt.show()

    distrib = tfp.distributions.Bernoulli(probs=probs)
    distrib = tfp.distributions.Independent(
        distribution=distrib, reinterpreted_batch_ndims=1)

    return distrib

# Now train the distributions with gradient tape
start_time = time.time()
trained_distrib = get_trained_distribution(x=x_train, y=y_train)
print("Training duration: %2.fs"%(time.time() - start_time))

# Compare the results.
log_probs = []
for x in x_test:
    log_prob = predict_log_prob(distribution=trained_distrib,
        prior=prior, sample=x)
    log_probs.append(log_prob)

y_pred = np.argmax(log_probs, axis=-1)
print("F1 from trained tfp:", metrics.f1_score(average="macro",
    y_true=y_test, y_pred=y_pred))
# Out:
# %-------------------%
# Class  0
# %-------------------%
# %-------------------%
# Class  1
# %-------------------%
# %-------------------%
# Class  2
# %-------------------%
# %-------------------%
# Class  3
# %-------------------%
# Training duration: 102s
# F1 from trained tfp: 0.826925403109056
