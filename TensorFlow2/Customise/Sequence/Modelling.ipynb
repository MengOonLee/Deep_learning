# %% [markdown]
# <a href="https://colab.research.google.com/github/MengOonLee/Deep_learning/blob/master/TensorFlow2/Tutorial/Customising_TensorFlow2_models/Sequence_modelling/Sequence_modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
# pip install --no-cache-dir -qU pip wheel
# pip install --no-cache-dir -qU numpy pandas matplotlib seaborn scikit-learn
# pip install --no-cache-dir -qU tensorflow
# pip check
# Out:
# No broken requirements found.

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import warnings
warnings.filterwarnings('ignore')

import numpy as np
np.random.seed(42)

import pandas as pd
import json

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

import seaborn as sns
sns.set_style('whitegrid')
sns.set(font='DejaVu Sans')

import tensorflow as tf
tf.keras.utils.set_random_seed(42)
tf.get_logger().setLevel('ERROR')

# %% [markdown]
# # Sequence modelling
#
# ## Coding tutorials
#  #### 1.  The IMDb dataset
#  #### 2. Padding and masking sequence data
#  #### 3. The `Embedding` layer
#  #### 4. The Embedding Projector
#  #### 5. Recurrent neural network layers
#  #### 6. Stacked RNNs and the `Bidirectional` wrapper

# %% [markdown]
# ***
# <a id="coding_tutorial_1"></a>
# ## The IMDb Dataset

# %%
test_input = [
    [4, 12, 33, 18],
    [63, 23, 54, 30, 19, 3],
    [43, 37, 11, 33, 15]
]

preprocessed_data = tf.keras.utils.pad_sequences(
    sequences=test_input, padding='pre',
    maxlen=5, truncating='post', value=-1
)
print(preprocessed_data)
# Out:
# [[-1  4 12 33 18]
#  [63 23 54 30 19]
#  [43 37 11 33 15]]

# %%
test_input = [
    [[2, 1], [3, 3]],
    [[4, 3], [2, 4], [1, 1]]
]

preprocessed_data = tf.keras.utils.pad_sequences(
    sequences=test_input, padding='post'
)
print(preprocessed_data)
# Out:
# [[[2 1]
#   [3 3]
#   [0 0]]
#
#  [[4 3]
#   [2 4]
#   [1 1]]]

# %% [markdown]
# #### Load the IMDB review sentiment dataset

# %%
# Import imdb

import tensorflow.keras.datasets.imdb as imdb

# %%
# Download and assign the data set using load_data()

(x_train, y_train), (x_test, y_test) = imdb.load_data()
# Out:
# ...
# 17465344/17464789 [==============================] - 0s 0us/step

# %% [markdown]
# #### Inspect the dataset

# %%
# Inspect the type of the data

type(x_train)
# Out:
# numpy.ndarray

# %%
# Inspect the shape of the data

x_train.shape
# Out:
# (25000,)

# %%
# Display the first dataset element input
# Notice encoding

print(x_train[0])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 22665, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 21631, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 19193, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 10311, 8, 4, 107, 117, 5952, 15, 256, 4, 31050, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 12118, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]

# %%
# Display the first dataset element output

y_train[0]
# Out:
# 1

# %% [markdown]
# #### Load dataset with different options

# %%
# Load the dataset with defaults

imdb.load_data(path='imdb.npz', index_from=3)

# ~/.keras/dataset/
# Out:
# ((array([list([1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 22665, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 21631, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 19193, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 10311, 8, 4, 107, 117, 5952, 15, 256, 4, 31050, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 12118, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]),
# ...

# %%
# Limit the vocabulary to the top 1000 words using num_words

imdb.load_data(num_words=1000)
# Out:
# ((array([list([1, 14, 22, 16, 43, 530, 973, 2, 2, 65, 458, 2, 66, 2, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 2, 2, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2, 19, 14, 22, 4, 2, 2, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 2, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2, 2, 16, 480, 66, 2, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 2, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 2, 15, 256, 4, 2, 7, 2, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 2, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2, 56, 26, 141, 6, 194, 2, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 2, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 2, 88, 12, 16, 283, 5, 16, 2, 113, 103, 32, 15, 16, 2, 19, 178, 32]),
# ...

# %%
# Ignore the top 10 most frequent words using skip_top

imdb.load_data(skip_top=10, num_words=1000, oov_char=2)
# Out:
# ((array([list([2, 14, 22, 16, 43, 530, 973, 2, 2, 65, 458, 2, 66, 2, 2, 173, 36, 256, 2, 25, 100, 43, 838, 112, 50, 670, 2, 2, 35, 480, 284, 2, 150, 2, 172, 112, 167, 2, 336, 385, 39, 2, 172, 2, 2, 17, 546, 38, 13, 447, 2, 192, 50, 16, 2, 147, 2, 19, 14, 22, 2, 2, 2, 469, 2, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 2, 2, 22, 17, 515, 17, 12, 16, 626, 18, 2, 2, 62, 386, 12, 2, 316, 2, 106, 2, 2, 2, 2, 16, 480, 66, 2, 33, 2, 130, 12, 16, 38, 619, 2, 25, 124, 51, 36, 135, 48, 25, 2, 33, 2, 22, 12, 215, 28, 77, 52, 2, 14, 407, 16, 82, 2, 2, 2, 107, 117, 2, 15, 256, 2, 2, 2, 2, 2, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 2, 2, 2, 2, 13, 104, 88, 2, 381, 15, 297, 98, 32, 2, 56, 26, 141, 2, 194, 2, 18, 2, 226, 22, 21, 134, 476, 26, 480, 2, 144, 30, 2, 18, 51, 36, 28, 224, 92, 25, 104, 2, 226, 65, 16, 38, 2, 88, 12, 16, 283, 2, 16, 2, 113, 103, 32, 15, 16, 2, 19, 178, 32]),
# ...

# %%
# Limit the sequence lengths to 500 using maxlen

imdb.load_data(maxlen=500)
# Out:
# ((array([list([1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 22665, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 21631, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 19193, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 10311, 8, 4, 107, 117, 5952, 15, 256, 4, 31050, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 12118, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]),
# ...

# %%
 # Use '1' as the character that indicates the start of a sequence

 imdb.load_data(start_char=1)
# Out:
# ((array([list([1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 22665, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 21631, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 19193, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 10311, 8, 4, 107, 117, 5952, 15, 256, 4, 31050, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 12118, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]),
# ...

# %% [markdown]
# #### Explore the dataset word index

# %%
# Load the imdb word index using get_word_index()

imdb_word_index = imdb.get_word_index()
# Out:
# ...
# 1646592/1641221 [==============================] - 0s 0us/step

# %%
# View the word index as a dictionary,
# accounting for index_from.

index_from = 3
imdb_word_index = {key: value + index_from for key, value in imdb_word_index.items()}

# %%
# Retrieve a specific word's index

print(imdb_word_index['simpsonian'])
print(imdb_word_index['the'])
# Out:
# 52256
# 4

# %%
# View an input sentence

inv_imdb_word_index = {value: key for key, value in imdb_word_index.items()}
print([inv_imdb_word_index[index] for index in x_train[0] if index > index_from])
# Out:
# ['this', 'film', 'was', 'just', 'brilliant', 'casting', 'location', 'scenery', 'story', 'direction', "everyone's", 'really', 'suited', 'the', 'part', 'they', 'played', 'and', 'you', 'could', 'just', 'imagine', 'being', 'there', 'robert', "redford's", 'is', 'an', 'amazing', 'actor', 'and', 'now', 'the', 'same', 'being', 'director', "norman's", 'father', 'came', 'from', 'the', 'same', 'scottish', 'island', 'as', 'myself', 'so', 'i', 'loved', 'the', 'fact', 'there', 'was', 'a', 'real', 'connection', 'with', 'this', 'film', 'the', 'witty', 'remarks', 'throughout', 'the', 'film', 'were', 'great', 'it', 'was', 'just', 'brilliant', 'so', 'much', 'that', 'i', 'bought', 'the', 'film', 'as', 'soon', 'as', 'it', 'was', 'released', 'for', 'retail', 'and', 'would', 'recommend', 'it', 'to', 'everyone', 'to', 'watch', 'and', 'the', 'fly', 'fishing', 'was', 'amazing', 'really', 'cried', 'at', 'the', 'end', 'it', 'was', 'so', 'sad', 'and', 'you', 'know', 'what', 'they', 'say', 'if', 'you', 'cry', 'at
# ...

# %%
# Get the sentiment value

y_train[0]
# Out:
# 1

# %% [markdown]
# ---
# <a id="coding_tutorial_2"></a>
# ## Padding and Masking Sequence Data

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Masking
import numpy as np

test_input = [
    [4, 12, 33],
    [63, 23, 54, 30, 19, 3],
    [43, 37, 11, 33]
]

preprocessed_data = pad_sequences(test_input, padding='post', maxlen=5,
    truncating='post', value=0)
print(preprocessed_data)

masking_layer = Masking(mask_value=0)
# (batch_size, seq_length, features)
preprocessed_data = preprocessed_data[..., np.newaxis]
masked_input = masking_layer(preprocessed_data)
print(masked_input._keras_mask)
# Out:
# [[ 4 12 33  0  0]
#  [63 23 54 30 19]
#  [43 37 11 33  0]]
# tf.Tensor(
# [[ True  True  True False False]
#  [ True  True  True  True  True]
#  [ True  True  True  True False]], shape=(3, 5), dtype=bool)

# %%
# Load the imdb data set

import tensorflow.keras.datasets.imdb as imdb
(x_train, y_train), (x_test, y_test) = imdb.load_data()

# %% [markdown]
# #### Preprocess the data with padding

# %%
# Inspect the input data shape

x_train.shape
# Out:
# (25000,)

# %%
# Pad the inputs to the maximum length using maxlen

padded_x_train = tf.keras.preprocessing.sequence.pad_sequences(
    x_train, maxlen=300, padding='post', truncating='pre')

# %%
# Inspect the output data shape

padded_x_train.shape
# Out:
# (25000, 300)

# %% [markdown]
# #### Create a Masking layer

# %%
# Import numpy 

import numpy as np

# %%
# Masking expects to see (batch, sequence, features)
# Create a dummy feature dimension using expand_dims

padded_x_train = np.expand_dims(padded_x_train, -1)
padded_x_train.shape
# Out:
# (25000, 300, 1)

# %%
# Create a Masking layer 

tf_x_train = tf.convert_to_tensor(padded_x_train, dtype='float32')
masking_layer = tf.keras.layers.Masking(mask_value=0.0)

# %%
# Pass tf_x_train to it

masked_x_train = masking_layer(tf_x_train)

# %%
# Look at the dataset

print(masked_x_train[0, :10])
# Out:
# tf.Tensor(
# [[1.000e+00]
#  [1.400e+01]
#  [2.200e+01]
#  [1.600e+01]
#  [4.300e+01]
#  [5.300e+02]
#  [9.730e+02]
#  [1.622e+03]
#  [1.385e+03]
#  [6.500e+01]], shape=(10, 1), dtype=float32)

# %%
# Look at the ._keras_mask for the dataset

masked_x_train._keras_mask
# Out:
# <tf.Tensor: shape=(25000, 300), dtype=bool, numpy=
# array([[ True,  True,  True, ..., False, False, False],
#        [ True,  True,  True, ..., False, False, False],
#        [ True,  True,  True, ..., False, False, False],
#        ...,
#        [ True,  True,  True, ..., False, False, False],
#        [ True,  True,  True, ..., False, False, False],
#        [ True,  True,  True, ..., False, False, False]])>

# %% [markdown]
# ***
# <a id="coding_tutorial_3"></a>
# ## The Embedding layer

# %%
import numpy as np
from tensorflow.keras.layers import Embedding

test_input = np.random.randint(1000, size=(16, 64))
print(test_input.shape)

embedding_layer = Embedding(1000, 32, input_length=64, mask_zero=True)
embedded_inputs = embedding_layer(test_input)
print(embedded_inputs.shape)
embedded_inputs._keras_mask
# Out:
# (16, 64)
# (16, 64, 32)
# <tf.Tensor: shape=(16, 64), dtype=bool, numpy=
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])>

# %% [markdown]
# #### Create and apply an `Embedding` layer

# %%
# Create an embedding layer using layers.Embedding
# Specify input_dim, output_dim, input_length

embedding_layer = tf.keras.layers.Embedding(input_dim=501,
    output_dim=16)

# %%
# Inspect an Embedding layer output for a fixed input
# Expects an input of shape (batch, sequence, feature)

sequence_of_indices = tf.constant([[[0], [1], [5], [500]]])
sequence_of_embeddings = embedding_layer(sequence_of_indices)
sequence_of_embeddings
# Out:
# <tf.Tensor: shape=(1, 4, 1, 16), dtype=float32, numpy=
# array([[[[-0.01045238,  0.03741701,  0.02744314, -0.00477697,
#            0.04993845, -0.00259789, -0.02369183,  0.04262223,
#            0.04675734, -0.02244818,  0.01439457, -0.01600119,
#           -0.00736012,  0.04170585,  0.00227375, -0.04061377]],
#
#         [[ 0.04101057,  0.01894107,  0.03398773,  0.00642778,
#            0.04834047,  0.01396563,  0.04129377, -0.04552003,
#           -0.04092155, -0.03561251,  0.02859272,  0.04923328,
#            0.0088479 ,  0.01477656, -0.01817548, -0.03077347]],
#
#         [[-0.02137947, -0.00985627,  0.04698112,  0.00586755,
#           -0.0440384 , -0.03868908,  0.00435785, -0.01943077,
#            0.04784031, -0.00929739, -0.00147948,  0.04799548,
#           -0.00613393,  0.0052299 , -0.03641131,  0.01235385]],
#
#         [[ 0.01008532,  0.03266043, -0.03428965, -0.00789673,
#           -0.00812177, -0.00613341, -0.00508987, -0.01784184,
# ...

# %%
# Inspect the Embedding layer weights using get_weights()

embedding_layer.get_weights()[0]
# Out:
# array([[-0.01045238,  0.03741701,  0.02744314, ...,  0.04170585,
#          0.00227375, -0.04061377],
#        [ 0.04101057,  0.01894107,  0.03398773, ...,  0.01477656,
#         -0.01817548, -0.03077347],
#        [-0.0043392 , -0.00345894, -0.01113782, ...,  0.0228515 ,
#         -0.03595222, -0.0165998 ],
#        ...,
#        [-0.01049829,  0.02713722, -0.02429829, ...,  0.01595649,
#         -0.04824808,  0.04716147],
#        [ 0.0131045 , -0.02047769, -0.04330591, ..., -0.04316322,
#         -0.02161652, -0.03340043],
#        [ 0.01008532,  0.03266043, -0.03428965, ..., -0.00496255,
#         -0.00596451,  0.02140781]], dtype=float32)

# %%
# Get the embedding for the 14th index

embedding_layer.get_weights()[0][14, :]
# Out:
# array([ 0.02854749,  0.04094912, -0.01184398, -0.02363014, -0.02977036,
#        -0.02971943,  0.01384654, -0.02188219,  0.00091917, -0.04484844,
#        -0.01591766,  0.02994293, -0.0370908 , -0.04779939, -0.04287604,
#        -0.02061696], dtype=float32)

# %% [markdown]
# #### Create and apply an `Embedding` layer that uses `mask_zero=True`

# %%
# Create a layer that uses the mask_zero kwarg

masking_embedding_layer = tf.keras.layers.Embedding(input_dim=501,
    output_dim=16, mask_zero=True)

# %%
# Apply this layer to the sequence and see the _keras_mask property

masked_sequence_of_embeddings = masking_embedding_layer(
    sequence_of_indices)
masked_sequence_of_embeddings._keras_mask
# Out:
# <tf.Tensor: shape=(1, 4, 1), dtype=bool, numpy=
# array([[[False],
#         [ True],
#         [ True],
#         [ True]]])>

# %% [markdown]
# ---
# <a id="coding_tutorial_4"></a>
# ## The Embedding Projector

# %% [markdown]
# #### Load and preprocess the IMDb data

# %%
# A function to load and preprocess the IMDB dataset

def get_and_pad_imdb_dataset(num_words=10000, maxlen=None, index_from=2):
    from tensorflow.keras.datasets import imdb

    # Load the reviews
    (x_train, y_train), (x_test, y_test) = imdb.load_data(path='imdb.npz',
        num_words=num_words, skip_top=0, maxlen=maxlen, start_char=1,
        oov_char=2, index_from=index_from)

    x_train = tf.keras.preprocessing.sequence.pad_sequences(x_train,
        maxlen=None, padding='pre', truncating='pre', value=0)
    
    x_test = tf.keras.preprocessing.sequence.pad_sequences(x_test,
        maxlen=None, padding='pre', truncating='pre', value=0)
    
    return (x_train, y_train), (x_test, y_test)

# %%
# Load the dataset

(x_train, y_train), (x_test, y_test) = get_and_pad_imdb_dataset()

# %%
# A function to get the dataset word index

def get_imdb_word_index(num_words=10000, index_from=2):
    imdb_word_index = tf.keras.datasets.imdb.get_word_index(
        path='imdb_word_index.json')
    imdb_word_index = {key: value + index_from for key, value 
        in imdb_word_index.items() if value <= num_words-index_from}
    return imdb_word_index

# %%
# Get the word index

imdb_word_index = get_imdb_word_index()

# %%
# Swap the keys and values of the word index

inv_imdb_word_index = {value: key for key, value in imdb_word_index.items()}

# %%
# View the first dataset example sentence

print([inv_imdb_word_index[index] for index in x_train[100] if index > 2])
# Out:
# ['i', 'am', 'a', 'great', 'fan', 'of', 'david', 'lynch', 'and', 'have', 'everything', 'that', "he's", 'made', 'on', 'dvd', 'except', 'for', 'hotel', 'room', 'the', '2', 'hour', 'twin', 'peaks', 'movie', 'so', 'when', 'i', 'found', 'out', 'about', 'this', 'i', 'immediately', 'grabbed', 'it', 'and', 'and', 'what', 'is', 'this', "it's", 'a', 'bunch', 'of', 'drawn', 'black', 'and', 'white', 'cartoons', 'that', 'are', 'loud', 'and', 'foul', 'mouthed', 'and', 'unfunny', 'maybe', 'i', "don't", 'know', "what's", 'good', 'but', 'maybe', 'this', 'is', 'just', 'a', 'bunch', 'of', 'crap', 'that', 'was', 'on', 'the', 'public', 'under', 'the', 'name', 'of', 'david', 'lynch', 'to', 'make', 'a', 'few', 'bucks', 'too', 'let', 'me', 'make', 'it', 'clear', 'that', 'i', "didn't", 'care', 'about', 'the', 'foul', 'language', 'part', 'but', 'had', 'to', 'keep', 'the', 'sound', 'because', 'my', 'neighbors', 'might', 'have', 'all', 'in', 'all', 'this', 'is', 'a', 'highly', 'disappointing', 'release', 'and', 
# ...

# %% [markdown]
# #### Build an Embedding layer into a model

# %%
# Get the maximum token value

max_index_value = max(imdb_word_index.values())

# %%
# Specify an embedding dimension

embedding_dim = 16

# %%
# Build a model using Sequential:
#     1. Embedding layer
#     2. GlobalAveragePooling1D
#     3. Dense

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, GlobalAveragePooling1D, \
    Dense

model = Sequential([
    Embedding(input_dim=max_index_value+1, output_dim=embedding_dim,
        mask_zero=False),
    GlobalAveragePooling1D(),
    Dense(units=1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_2 (Embedding)      (None, None, 16)          160016
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 17
# ...
# Total params: 160,033
# Trainable params: 160,033
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Functional API refresher: use the Model to build the same model

from tensorflow.keras import Input, Model

review_sequence = Input((None, ))
embedding_sequence = Embedding(input_dim=max_index_value+1,
    output_dim=embedding_dim)(review_sequence)
average_embedding = GlobalAveragePooling1D()(embedding_sequence)
positive_probability = Dense(units=1, activation='sigmoid')(average_embedding)

model = Model(inputs=review_sequence, outputs=positive_probability)

model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# embedding_3 (Embedding)      (None, None, 16)          160016
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# ...
# Total params: 160,033
# Trainable params: 160,033
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Compile, train, and evaluate the model

# %%
# Compile the model with a binary cross-entropy loss

model.compile(loss='binary_crossentropy', metrics=['accuracy'],
    optimizer='adam')

# %%
# Train the model using .fit(), savng its history

history = model.fit(x_train, y_train, epochs=5, batch_size=32, 
    validation_data=(x_test, y_test), validation_steps=20)
# Out:
# Epoch 1/5
# 782/782 [==============================] - 6s 8ms/step - loss: 0.6901 - accuracy: 0.5649 - val_loss: 0.6846 - val_accuracy: 0.6016
# Epoch 2/5
# 782/782 [==============================] - 6s 7ms/step - loss: 0.6712 - accuracy: 0.6680 - val_loss: 0.6516 - val_accuracy: 0.6391
# Epoch 3/5
# 782/782 [==============================] - 6s 7ms/step - loss: 0.6298 - accuracy: 0.7555 - val_loss: 0.6028 - val_accuracy: 0.7547
# Epoch 4/5
# 782/782 [==============================] - 6s 7ms/step - loss: 0.5790 - accuracy: 0.7900 - val_loss: 0.5543 - val_accuracy: 0.7875
# Epoch 5/5
# 782/782 [==============================] - 6s 7ms/step - loss: 0.5298 - accuracy: 0.8168 - val_loss: 0.5120 - val_accuracy: 0.8016

# %%
# Plot the training and validation accuracy

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

history_dict = history.history

acc      = history_dict['accuracy']
val_acc  = history_dict['val_accuracy']
loss     = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(acc) + 1)

plt.figure(figsize=(14,5))
plt.plot(epochs, acc, marker='.', label='Training acc')
plt.plot(epochs, val_acc, marker='.', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Classification accuracy')
plt.legend(loc='lower right')
plt.ylim(0, 1);

# %% [markdown]
# #### The TensorFlow embedding projector
#
# The Tensorflow embedding projector can be found [here](https://projector.tensorflow.org/).

# %%
# Retrieve the embedding layer's weights from the trained model

weights = model.layers[1].get_weights()[0]

# %%
# Save the word Embeddings to tsv files
# Two files: 
#     one contains the embedding labels (meta.tsv),
#     one contains the embeddings (vecs.tsv)

import io
import os
from os import path

if not path.exists('data'):
    os.makedirs('data')

out_v = io.open(path.join('data', 'vecs.tsv'), 'w', encoding='utf-8')
out_m = io.open(path.join('data', 'meta.tsv'), 'w', encoding='utf-8')

k = 0

for word, token in imdb_word_index.items():
    if k != 0:
        out_m.write('\n')
        out_v.write('\n')
    
    out_v.write('\t'.join([str(x) for x in weights[token]]))
    out_m.write(word)
    k += 1
    
out_v.close()
out_m.close()
# beware large collections of embeddings!

# %% [markdown]
# ---
# <a id="coding_tutorial_5"></a>
# ## Recurrent neural network layers

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense

model = Sequential([
    Embedding(1000, 32),
    GRU(64, activation='tanh'),
    Dense(5, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding (Embedding)        (None, None, 32)          32000
# _________________________________________________________________
# gru (GRU)                    (None, 64)                18816
# _________________________________________________________________
# dense (Dense)                (None, 5)                 325
# ...
# Total params: 51,141
# Trainable params: 51,141
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Initialize and pass an input to a SimpleRNN layer

# %%
# Create a SimpleRNN layer and test it

from tensorflow.keras.layers import SimpleRNN

simplernn_layer = SimpleRNN(units=16)

# %%
# Note that only the final cell output is returned

sequence = tf.constant([[[1., 1.], [2., 2.], [56., -100.]]])
layer_output = simplernn_layer(sequence)
layer_output
# Out:
# <tf.Tensor: shape=(1, 16), dtype=float32, numpy=
# array([[ 1.        , -1.        ,  1.        ,  1.        ,  1.        ,
#         -0.99992657, -1.        ,  1.        ,  0.99999875,  1.        ,
#          1.        , -1.        ,  1.        ,  1.        ,  1.        ,
#          1.        ]], dtype=float32)>

# %% [markdown]
# #### Load and transform the IMDB review sentiment dataset

# %%
# A function to load and preprocess the IMDB dataset

def get_and_pad_imdb_dataset(num_words=10000, maxlen=None, index_from=2):
    from tensorflow.keras.datasets import imdb

    # Load the reviews
    (x_train, y_train), (x_test, y_test) = imdb.load_data(path='imdb.npz',
        num_words=num_words, skip_top=0, maxlen=maxlen, start_char=1,
        oov_char=2, index_from=index_from)

    x_train = tf.keras.preprocessing.sequence.pad_sequences(x_train,
        maxlen=None, padding='pre', truncating='pre', value=0)
    
    x_test = tf.keras.preprocessing.sequence.pad_sequences(x_test,
        maxlen=None, padding='pre', truncating='pre', value=0)
    
    return (x_train, y_train), (x_test, y_test)

# %%
# Load the dataset

(x_train, y_train), (x_test, y_test) = get_and_pad_imdb_dataset(maxlen=250)
# Out:
# ...
# 17465344/17464789 [==============================] - 0s 0us/step

# %%
# A function to get the dataset word index

def get_imdb_word_index(num_words=10000, index_from=2):
    imdb_word_index = tf.keras.datasets.imdb.get_word_index(
        path='imdb_word_index.json')
    imdb_word_index = {key: value + index_from for key, value 
        in imdb_word_index.items() if value <= num_words-index_from}
    return imdb_word_index

# %%
# Get the word index using get_imdb_word_index()

imdb_word_index = get_imdb_word_index()
# Out:
# ...
# 1646592/1641221 [==============================] - 0s 0us/step

# %% [markdown]
# #### Create a recurrent neural network model

# %%
# Get the maximum index value

max_index_value = max(imdb_word_index.values())
embedding_dim = 16

# %%
# Using Sequential, build the model:
# 1. Embedding.
# 2. LSTM.
# 3. Dense.

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

model = Sequential([
    Embedding(input_dim=max_index_value+1, 
        output_dim=embedding_dim, mask_zero=True),
    LSTM(units=16),
    Dense(units=1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_1 (Embedding)      (None, None, 16)          160016
# _________________________________________________________________
# lstm (LSTM)                  (None, 16)                2112
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# ...
# Total params: 162,145
# Trainable params: 162,145
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Compile and fit the model

# %%
# Compile the model with binary cross-entropy loss

model.compile(loss='binary_crossentropy', metrics=['accuracy'],
    optimizer='adam')

# %%
# Fit the model and save its training history

history = model.fit(x_train, y_train, epochs=3, batch_size=32, 
    validation_data=(x_test, y_test))
# Out:
# Epoch 1/3
# 536/536 [==============================] - 312s 582ms/step - loss: 0.4335 - accuracy: 0.7924 - val_loss: 0.3690 - val_accuracy: 0.8572
# Epoch 2/3
# 536/536 [==============================] - 298s 556ms/step - loss: 0.2297 - accuracy: 0.9135 - val_loss: 0.3375 - val_accuracy: 0.8675
# Epoch 3/3
# 536/536 [==============================] - 295s 550ms/step - loss: 0.1712 - accuracy: 0.9394 - val_loss: 0.3198 - val_accuracy: 0.8664

# %% [markdown]
# #### Plot learning curves

# %%
# Plot the training and validation accuracy

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

history_dict = history.history

acc      = history_dict['accuracy']
val_acc  = history_dict['val_accuracy']
loss     = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(acc) + 1)

plt.figure(figsize=(14,5))
plt.plot(epochs, acc, marker='.', label='Training acc')
plt.plot(epochs, val_acc, marker='.', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Classification accuracy')
plt.legend(loc='lower right')
plt.ylim(0, 1);

# %% [markdown]
# #### Make predictions with the model

# %%
# View the first test data example sentence
# (invert the word index)

inv_imdb_word_index = {value: key for key, value in imdb_word_index.items()}
print([inv_imdb_word_index[index] for index in x_test[0] if index > 2])
# Out:
# ['please', 'give', 'this', 'one', 'a', 'miss', 'br', 'br', 'and', 'the', 'rest', 'of', 'the', 'cast', 'rendered', 'terrible', 'performances', 'the', 'show', 'is', 'flat', 'flat', 'flat', 'br', 'br', 'i', "don't", 'know', 'how', 'michael', 'madison', 'could', 'have', 'allowed', 'this', 'one', 'on', 'his', 'plate', 'he', 'almost', 'seemed', 'to', 'know', 'this', "wasn't", 'going', 'to', 'work', 'out', 'and', 'his', 'performance', 'was', 'quite', 'so', 'all', 'you', 'madison', 'fans', 'give', 'this', 'a', 'miss']

# %%
# Get the model prediction using model.predict()

model.predict(x_test[None, 0, :])
# Out:
# array([[0.07616445]], dtype=float32)

# %%
# Get the corresponding label

y_test[0]
# Out:
# 0

# %% [markdown]
# ---
# <a id="coding_tutorial_6"></a>
# ## Stacked RNNs and the Bidirectional wrapper

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Masking, LSTM, Dense, \
    Bidirectional

inputs = Input(shape=(None, 10))
h = Masking(mask_value=0)(inputs)
h = Bidirectional(LSTM(32, return_sequences=True),
    merge_mode='sum')(h)
h = Bidirectional(LSTM(64))(h)
outputs = Dense(5, activation='softmax')(h)

model = Model(inputs, outputs)

model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, None, 10)]        0
# _________________________________________________________________
# masking (Masking)            (None, None, 10)          0
# _________________________________________________________________
# bidirectional (Bidirectional (None, None, 32)          11008
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 128)               49664
# _________________________________________________________________
# dense (Dense)                (None, 5)                 645
# ...
# Total params: 61,317
# Trainable params: 61,317
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Load and transform the IMDb review sentiment dataset

# %%
# A function to load and preprocess the IMDB dataset

def get_and_pad_imdb_dataset(num_words=10000, maxlen=None, index_from=2):
    from tensorflow.keras.datasets import imdb

    # Load the reviews
    (x_train, y_train), (x_test, y_test) = imdb.load_data(
        path='imdb.npz', num_words=num_words, skip_top=0, maxlen=maxlen,
        start_char=1, oov_char=2, index_from=index_from)

    x_train = tf.keras.preprocessing.sequence.pad_sequences(
        x_train, maxlen=None, padding='pre', truncating='pre', value=0)
    
    x_test = tf.keras.preprocessing.sequence.pad_sequences(
        x_test, maxlen=None, padding='pre', truncating='pre', value=0)
    return (x_train, y_train), (x_test, y_test)

# %%
# Load the dataset

(x_train, y_train), (x_test, y_test) = get_and_pad_imdb_dataset(
    num_words=5000, maxlen=250)
# Out:
# ...
# 17465344/17464789 [==============================] - 1s 0us/step

# %%
# A function to get the dataset word index

def get_imdb_word_index(num_words=10000, index_from=2):
    imdb_word_index = tf.keras.datasets.imdb.get_word_index(
        path='imdb_word_index.json')
    imdb_word_index = {key: value + index_from for key, value 
        in imdb_word_index.items() if value <= num_words-index_from}
    return imdb_word_index

# %%
# Get the word index using get_imdb_word_index()

imdb_word_index = get_imdb_word_index(num_words=5000)
# Out:
# ...
# 1646592/1641221 [==============================] - 0s 0us/step

# %% [markdown]
# #### Build stacked and bidirectional recurrent models

# %%
# Get the maximum index value and specify an embedding dimension

max_index_value = max(imdb_word_index.values())
embedding_dim = 16

# %%
# Using Sequential, build a stacked LSTM model via return_sequences=True

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

model = Sequential([
    Embedding(input_dim=max_index_value+1, output_dim=embedding_dim,
        mask_zero=True),
    LSTM(units=32, return_sequences=True),
    LSTM(units=32, return_sequences=False),
    Dense(units=1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding (Embedding)        (None, None, 16)          80016
# _________________________________________________________________
# lstm_2 (LSTM)                (None, None, 32)          6272
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# ...
# Total params: 94,641
# Trainable params: 94,641
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Using Sequential, build a bidirectional RNN with merge_mode='sum'

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, \
    Bidirectional, GRU

model = Sequential([
    Embedding(input_dim=max_index_value+1, output_dim=embedding_dim,
        mask_zero=True),
    Bidirectional(layer=LSTM(units=8), merge_mode='sum',
        backward_layer=GRU(units=8, go_backwards=True)),
    Dense(units=1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_1 (Embedding)      (None, None, 16)          80016
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 8)                 1424
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# ...
# Total params: 81,449
# Trainable params: 81,449
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Create a model featuring both stacked recurrent layers and a bidirectional layer

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, \
    Bidirectional, GRU

model = Sequential([
    Embedding(input_dim=max_index_value+1, output_dim=embedding_dim),
    Bidirectional(layer=LSTM(units=8, return_sequences=True), 
        merge_mode='concat'),
    GRU(units=8, return_sequences=False),
    Dense(units=1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_2 (Embedding)      (None, None, 16)          80016
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, None, 16)          1600
# _________________________________________________________________
# gru_1 (GRU)                  (None, 8)                 624
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# ...
# Total params: 82,249
# Trainable params: 82,249
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Compile and fit the model

# %%
# Compile the model

model.compile(loss='binary_crossentropy', metrics=['accuracy'],
    optimizer='adam')

# %%
# Train the model, saving its history

history = model.fit(x_train, y_train, epochs=3, batch_size=32,
    validation_data=(x_test, y_test))
# Out:
# Epoch 1/3
# 536/536 [==============================] - 23s 42ms/step - loss: 0.4315 - accuracy: 0.8007 - val_loss: 0.3340 - val_accuracy: 0.8627
# Epoch 2/3
# 536/536 [==============================] - 21s 40ms/step - loss: 0.2571 - accuracy: 0.9040 - val_loss: 0.3042 - val_accuracy: 0.8763
# Epoch 3/3
# 536/536 [==============================] - 21s 40ms/step - loss: 0.2029 - accuracy: 0.9264 - val_loss: 0.3616 - val_accuracy: 0.8579

# %%
# Plot the training and validation accuracy

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

history_dict = history.history

acc      = history_dict['accuracy']
val_acc  = history_dict['val_accuracy']
loss     = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(acc) + 1)

plt.figure(figsize=(14,5))
plt.plot(epochs, acc, marker='.', label='Training acc')
plt.plot(epochs, val_acc, marker='.', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Classification accuracy')
plt.legend(loc='lower right')
plt.ylim(0, 1);
